# %%
import numpy as np
import cv2
from sklearn.neighbors import KNeighborsClassifier

# %%
data=np.load("face_data.npy")

# %%
print(data.shape)
# Out:
# (38, 10001)

# %%
X=data[:, 1:].astype(int)
y=data[:, 0]
X,y
# Out:
# (array([[ 70,  85, 155, ...,  33,  35,  54],
#         [159, 164, 167, ...,  30,  30,  31],
#         [159, 156, 156, ..., 214, 205, 206],
#         ...,
#         [ 38,  37,  34, ...,  27,  28,  27],
#         [ 33,  33,  34, ...,  23,  23,  24],
#         [ 96, 180, 192, ..., 204, 206, 168]]),
#  array(['Ana', 'Ana', 'Ana', 'Ana', 'Ana', 'Ana', 'Ana', 'Ana', 'Ana',
#         'Ana', 'Ana', 'Ana', 'Ana', 'Ana', 'Ana', 'Ana', 'Adi', 'Adi',
#         'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi',
#         'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi', 'Adi',
#         'Adi', 'Adi'], dtype='<U3'))

# %%
model=KNeighborsClassifier()
model.fit(X,y)
# Out:
# KNeighborsClassifier()

# %%
cap=cv2.VideoCapture(0)
detector=cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')
while True:
    ret, frame=cap.read()
    if ret:
        faces=detector.detectMultiScale(frame)
        for face in faces:
            x, y, w, h=face
            cut=frame[y:y+h, x:x+w]
            fix=cv2.resize(cut, (100,100))
            gray=cv2.cvtColor(fix, cv2.COLOR_BGR2GRAY)
            out=model.predict([gray.flatten()])
            cv2.rectangle(frame, (x, y),(x+w,y+h),(255,0,0), 2)
            cv2.putText(frame, str(out[0]), (x,y-10), cv2.FONT_HERSHEY_COMPLEX,2,(255,0,0),2)
            print(out)
            cv2.imshow("My Face", gray)
        cv2.imshow("My Frame", frame)
        
    key=cv2.waitKey(1)
    if key==ord("q"):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Adi']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Adi']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
# ['Ana']
